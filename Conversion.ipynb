# %%
! ctml2yaml --help
# Out:
# usage: ctml2yaml [-h] input [output]
#
# Convert legacy CTML input files to YAML format
#
# positional arguments:
#   input       The input CTML filename. Must be specified.
#   output      The output YAML filename. Optional.
#
# optional arguments:
#   -h, --help  show this help message and exit
#
# The 'output' argument is optional. If it is not given, an output file with the
# same name as the input file is used, with the extension changed to '.yaml'.

# %%
! ctml2yaml C12H26_NOX_27_452_20_TJ.xml C12H26_Nox.yaml
# Out:
# Traceback (most recent call last):
#   File "C:\Users\aetor\anaconda3\envs\MECH652\Scripts\ctml2yaml-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\Users\aetor\anaconda3\envs\MECH652\lib\site-packages\cantera\ctml2yaml.py", line 2692, in main
#     convert(input_file, output_file)
#   File "C:\Users\aetor\anaconda3\envs\MECH652\lib\site-packages\cantera\ctml2yaml.py", line 2607, in convert
#     phases = create_phases_from_data_node(ctml_tree, species_data, reaction_data)
#   File "C:\Users\aetor\anaconda3\envs\MECH652\lib\site-packages\cantera\ctml2yaml.py", line 2545, in create_phases_from_data_node
#     phases = [
#   File "C:\Users\aetor\anaconda3\envs\MECH652\lib\site-packages\cantera\ctml2yaml.py", line 2546, in <listcomp>
#     Phase(node, species_data, reaction_data) for node in ctml_tree.iterfind("phase")
#   File "C:\Users\aetor\anaconda3\envs\MECH652\lib\site-packages\cantera\ctml2yaml.py", line 592, in __init__
# ...

# %%
! ck2yaml --input=dodeane_Nox/chem-Cai-S141+NOx.inp --thermo=dodeane_Nox/therm-Cai-S141+NOx.dat --transport=dodeane_Nox/tran-Cai-S141+NOx.dat
# Out:
# Skipping unexpected species "HE" while reading thermodynamics entry.
# Skipping unexpected species "O2CHO" while reading thermodynamics entry.
# Skipping unexpected species "HO2CHO" while reading thermodynamics entry.
# Skipping unexpected species "OCHO" while reading thermodynamics entry.
# Skipping unexpected species "CH2OH" while reading thermodynamics entry.
# Skipping unexpected species "OCH2O2H" while reading thermodynamics entry.
# Skipping unexpected species "HOCH2O2" while reading thermodynamics entry.
# Skipping unexpected species "HOCH2O2H" while reading thermodynamics entry.
# Skipping unexpected species "CH" while reading thermodynamics entry.
# Skipping unexpected species "C" while reading thermodynamics entry.
# Skipping unexpected species "C2H4O2H" while reading thermodynamics entry.
# Skipping unexpected species "C2H4O1X2" while reading thermodynamics entry.
# Skipping unexpected species "CH3CO3" while reading thermodynamics entry.
# ...
